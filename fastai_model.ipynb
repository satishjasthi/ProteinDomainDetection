# %%
from fastai.vision.all import *

# %%
dls = ImageDataLoaders.from_folder('/home/satish27may/ProteinDomainDetection/data/Classification/images_224',train='train', valid='val' )
dls.show_batch()

# %%
learn = cnn_learner(dls, resnet34, metrics=accuracy)
learn.fine_tune(1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.86% [1/35 00:33<18:43]
#     </div>

# %%
# ?ImageDataLoaders.from_folder
# Out:
# Signature: ImageDataLoaders.from_folder(path, train='train', valid='valid', valid_pct=None, seed=None, vocab=None, item_tfms=None, batch_tfms=None, bs=64, val_bs=None, shuffle_train=True, device=None)
# Docstring: Create from imagenet style dataset in `path` with `train` and `valid` subfolders (or provide `valid_pct`)
# File:      ~/anaconda3/envs/detectron2/lib/python3.7/site-packages/fastai/vision/data.py
# Type:      method

# %%
learn.show_results()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c3b657dcc9ae> in <module>()
# ----> 1 learn.show_results()
#
# /home/satish27may/anaconda3/envs/detectron2/lib/python3.7/site-packages/fastai/learner.py in show_results(self, ds_idx, dl, max_n, shuffle, **kwargs)
#     259     def show_results(self, ds_idx=1, dl=None, max_n=9, shuffle=True, **kwargs):
#     260         if dl is None: dl = self.dls[ds_idx].new(shuffle=shuffle)
# --> 261         b = dl.one_batch()
#     262         _,_,preds = self.get_preds(dl=[b], with_decoded=True)
#     263         self.dls.show_results(b, preds, max_n=max_n, **kwargs)
#
# /home/satish27may/anaconda3/envs/detectron2/lib/python3.7/site-packages/fastai/data/load.py in one_batch(self)
#     134     def to(self, device): self.device = device
#     135     def one_batch(self):
# --> 136         if self.n is not None and len(self)==0: raise ValueError(f'This DataLoader does not contain any batches')
#     137         with self.fake_l.no_multiproc(): res = first(self)
#     138         if hasattr(self, 'it'): delattr(self, 'it')
#
# ValueError: This DataLoader does not contain any batches

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(dls.valid_ds)==len(losses)==len(idxs)
interp.plot_confusion_matrix(figsize=(7,7))
